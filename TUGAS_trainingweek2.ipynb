# %%
import pandas as pd

# %%
iris = pd.read_csv('http://data.jakarta.go.id/dataset/b3927bd4-f21f-4253-9858-5fa4f677d213/resource/03266a68-1c1b-4848-aebe-f671e4e41ee6/download/JUMLAH-KEPADATAN-PENDUDUK-PER-KELURAHAN-2019.csv')

# %%
iris.head()
# Out:
#    tahun         nama_provinsi nama_kabupaten_kota   nama_kecamatan  \
# 0   2019  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 1   2019  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 2   2019  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU UTR
# 3   2019  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
# 4   2019  PROVINSI DKI JAKARTA  KAB.ADM.KEP.SERIBU  KEP. SERIBU SLT
#
#    nama_kelurahan  jumlah_luas_wilayah_(km2)  jumlah_kepadatan_(jiwa/km2)  \
# 0     P. PANGGANG                       0.62                 11373.590980
# 1       P. KELAPA                       2.58                  2776.724572
# 2      P. HARAPAN                       2.45                  1080.418437
# 3  P. UNTUNG JAWA                       1.03                  2425.862907
# 4       P. TIDUNG                       1.07                  5608.980355
#
#    Unnamed: 7 Unnamed: 8
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# ...

# %%
iris.tail()
# Out:
#      tahun         nama_provinsi nama_kabupaten_kota nama_kecamatan  \
# 262   2019  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 263   2019  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 264   2019  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 265   2019  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
# 266   2019  PROVINSI DKI JAKARTA       JAKARTA TIMUR       CIPAYUNG
#
#     nama_kelurahan  jumlah_luas_wilayah_(km2)  jumlah_kepadatan_(jiwa/km2)  \
# 262         MUNJUL                       1.90                 15244.876510
# 263           SETU                       3.25                  7657.480315
# 264     BAMBU APUS                       3.17                 10055.920640
# 265   LUBANG BUAYA                       3.72                 20917.786140
# 266          CEGER                       3.63                  6398.234970
#
#      Unnamed: 7 Unnamed: 8
# 262         NaN        NaN
# 263         NaN        NaN
# ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
# tahun                          267 non-null int64
# nama_provinsi                  267 non-null object
# nama_kabupaten_kota            267 non-null object
# nama_kecamatan                 267 non-null object
# nama_kelurahan                 267 non-null object
# jumlah_luas_wilayah_(km2)      267 non-null float64
# jumlah_kepadatan_(jiwa/km2)    267 non-null float64
# Unnamed: 7                     0 non-null float64
# Unnamed: 8                     1 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 18.9+ KB

# %%
iris.describe()
# Out:
#         tahun  jumlah_luas_wilayah_(km2)  jumlah_kepadatan_(jiwa/km2)  \
# count   267.0                 267.000000                   267.000000
# mean   2019.0                   2.445543                 23814.282836
# std       0.0                   2.072991                 16860.892650
# min    2019.0                   0.140000                  1080.418437
# 25%    2019.0                   0.965000                 12720.195280
# 50%    2019.0                   1.790000                 18696.331360
# 75%    2019.0                   3.300000                 30403.333525
# max    2019.0                  13.070000                 95676.100630
#
#        Unnamed: 7
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
iris.groupby('tahun') .mean()
# Out:
#        jumlah_luas_wilayah_(km2)  jumlah_kepadatan_(jiwa/km2)  Unnamed: 7
# tahun
# 2019                    2.445543                 23814.282836         NaN

# %%
plt.figure(figsize=(10,5))
plt.plot(iris['tahun'], label='Tahun')
plt.plot(iris['nama_provinsi'], label='Nama Provinsi')
plt.plot(iris['nama_kabupaten_kota'], label='Nama Kabupaten Kota')
plt.plot(iris['nama_kecamatan'], label='Nama Kecamatan')
plt.plot(iris['nama_kelurahan'], label='Nama Kelurahan')
plt.plot(iris['jumlah_luas_wilayah_(km2)'], label='jumlah Luas Wilayah km2')
plt.plot(iris['jumlah_kepadatan_(jiwa/km2)'], label='Jumlah Kepadatan Jiwa')
           
plt.xlabel('luas wilayah')
plt.ylabel('kepadatan penduduk')
plt.title('kepadatan penduduk vs luas wilayah DKI JAKARTA')
plt.legend()
plt.show()
